# %% [markdown]
# # **KLASIFIKASI KANKER PAYUDARA MENGGUNAKAN SVM**

# %% [markdown]
# ## **Deklarasi library dan Load Data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/content/Wisconsin_BreastCancer_Data-With_MissingData (1).csv')

# %%
df.head()
# Out:
#          ID Diagnosis  Radius  Texture  Perimeter    Area  Smoothness  \
# 0    842302         M   17.99    10.38     122.80  1001.0      0.1184
# 1    842517         M   20.57    17.77     132.90  1326.0         NaN
# 2  84300903         M   19.69    21.25     130.00  1203.0      0.1096
# 3  84348301         M   11.42    20.38      77.58   386.1      0.1425
# 4  84358402         M   20.29    14.34     135.10  1297.0      0.1003
#
#    Compactness  Concavity  ConcavePoints  Symmetry  FractalDimension
# 0      0.27760     0.3001        0.14710    0.2419           0.07871
# 1      0.07864     0.0869        0.07017    0.1812           0.05667
# 2      0.15990     0.1974        0.12790    0.2069           0.05999
# 3      0.28390        NaN        0.10520    0.2597               NaN
# 4      0.13280     0.1980        0.10430    0.1809           0.05883

# %% [markdown]
# ## **Explorasi Data**

# %% [markdown]
# ### Cek Data Tiap Atribut

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                569 non-null    int64
#  1   Diagnosis         569 non-null    object
#  2   Radius            566 non-null    float64
#  3   Texture           566 non-null    float64
#  4   Perimeter         569 non-null    float64
#  5   Area              569 non-null    float64
#  6   Smoothness        565 non-null    float64
#  7   Compactness       569 non-null    float64
#  8   Concavity         565 non-null    float64
#  9   ConcavePoints     569 non-null    float64
#  10  Symmetry          569 non-null    float64
#  11  FractalDimension  564 non-null    float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 53.5+ KB

# %% [markdown]
# ### Cek Missing Value

# %%
df.isna().sum()
# Out:
# ID                  0
# Diagnosis           0
# Radius              3
# Texture             3
# Perimeter           0
# Area                0
# Smoothness          4
# Compactness         0
# Concavity           4
# ConcavePoints       0
# Symmetry            0
# FractalDimension    5
# dtype: int64

# %% [markdown]
# ### Hapus Baris Yang Mengandung Data NaN

# %%
df = df.dropna()

# %% [markdown]
# ### Ubah tiap nilai Atribut Diagnosis ke bilangan bulat

# %% [markdown]
# Ubah nilai 'B' menjadi nilai 0 sedangkan nilai 'M' menjadi nilai 1

# %%
df.drop('ID', axis=1, inplace=True)
df['Diagnosis'] = df['Diagnosis'].map({'B': 0, 'M': 1})

# %% [markdown]
# ### Grafik Tiap Atribut

# %%
import matplotlib.pyplot as plt
df.hist(bins=50,figsize=(30,20))
plt.show()

# %%
import matplotlib.pyplot as plt
df[df['Diagnosis']==0].hist(bins=50,figsize=(30,20))
plt.show()

# %%
import matplotlib.pyplot as plt
df[df['Diagnosis']==1].hist(bins=50,figsize=(30,20))
plt.show()

# %% [markdown]
# ### Frekuensi Setiap Atribut Diagnosis

# %%
df['Diagnosis'].value_counts().plot.bar()

# %% [markdown]
# ### Ekstraksi Variabel Y

# %%
target = df.pop('Diagnosis')

# %% [markdown]
# ## **Split Data menjadi data training dan data test dengan formasi 80:20**

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(df, target, test_size = 0.2, random_state = 2021)

# %% [markdown]
# ## **Model Training**

# %% [markdown]
# ### Training model

# %%
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

acc_model = []
param = [0.01, 0.05, 0.25, 0.5, 0.75, 1]
for c in param:
    svm = LinearSVC(C=c)
    svm.fit(X_train,y_train)
    print('Akurasi untuk c = %s: %s' %(c, accuracy_score(y_valid, svm.predict(X_valid))))
    acc_model.append(accuracy_score(y_valid, svm.predict(X_valid)))
# Out:
# Akurasi untuk c = 0.01: 0.8828828828828829
# Akurasi untuk c = 0.05: 0.918918918918919
# Akurasi untuk c = 0.25: 0.8558558558558559
# Akurasi untuk c = 0.5: 0.8108108108108109
# Akurasi untuk c = 0.75: 0.8738738738738738
# Akurasi untuk c = 1: 0.8558558558558559
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,

# %% [markdown]
# ### Training Ulang Model

# %%
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

svm = LinearSVC(C=0.05)
svm.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# LinearSVC(C=0.05)

# %% [markdown]
# ## **Evaluasi Model**

# %% [markdown]
# ### Menampilkan Confussion Matrix

# %%
from sklearn.metrics import  confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import metrics

y_pred = svm.predict(X_valid)
confusion_matrix = confusion_matrix(y_valid, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix, display_labels = [False, True])
cm_display.plot()
plt.show()

# %% [markdown]
# ### Menampilkan Hasil Perhitungan Evaluasi

# %% [markdown]
# Hasil Perhitungan Evaluasi Ini menggunakan akurasi, presisi, recall dan f1-score dengan menggunakan data confussion matrix

# %%
print(classification_report(y_valid, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94        75
#            1       0.91      0.81      0.85        36
#
#     accuracy                           0.91       111
#    macro avg       0.91      0.88      0.89       111
# weighted avg       0.91      0.91      0.91       111

# %% [markdown]
# ### Menampilkan Akurasi Model

# %%
print('Accuracy score model final: %s ' %accuracy_score(y_valid, svm.predict(X_valid)))
# Out:
# Accuracy score model final: 0.9099099099099099
