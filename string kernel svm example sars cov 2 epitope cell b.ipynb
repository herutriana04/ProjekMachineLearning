# %%
# !pip install string-kernels --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
from sklearn import svm
from stringkernels.kernels import string_kernel

# %%
# Basic packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
# Sklearn modules & classes
from sklearn.linear_model import Perceptron, LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn import metrics


# check version number
import imblearn

# %%
df = pd.read_csv('/content/dataset-epitope-sars-cov-2-clean-sum-div.csv')
df = df.sample(frac=1).reset_index()

# %%
df.head()
# Out:
#    Unnamed: 0  index  Unnamed: 0.1   Description  Starting Position  \
# 0           0      1             1  KPFERDISTEIY              462.0
# 1           1      2             2  KPLEFGATSAAL              958.0
# 2           2      3             3  LGAENSVAYSNN              699.0
# 3           3      4             4  REGVFVSNGTHW             1091.0
# 4           4      5             5  VQELYSPIFLIV               93.0
#
#    Ending Position                                       Antigen Name  \
# 0            473.0  surface glycoprotein [Severe acute respiratory...
# 1            969.0  orf1ab polyprotein [Severe acute respiratory s...
# 2            710.0                                 Spike glycoprotein
# 3           1102.0                                 Spike glycoprotein
# 4            104.0  ORF7a protein [Severe acute respiratory syndro...
#
#   Antigen Accession             Parent Protein Parent Protein Accession  ...  \
# ...

# %%
X = df['Description']
Y = df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1, stratify=Y)

# %%
# Instantiate the Support Vector Classifier (SVC)
svc = SVC(C=1.0, random_state=1, kernel=string_kernel(),probability=True)
 
# Fit the model
svc.fit(X_train, y_train)
# Out:
# SVC(kernel=functools.partial(<function string_kernel_multithread at 0x7f3ce1274050>, normalize=True, n_jobs=None),
#     probability=True, random_state=1)

# %%
# Make the predictions
y_predict = svc.predict(X_test)
 
# Measure the performance
print("Accuracy score %.3f" %metrics.accuracy_score(y_test, y_predict))
# Out:
# Accuracy score 0.513

# %%
testo1 = X_test[196]
print(testo1)
print(y_test[196])
testoR = svc.predict(testo1)
testoR
# Out:
# DSKVGGNYNYLY
# Negative
# array(['Negative', 'Negative', 'Negative', 'Negative', 'Negative',
#        'Negative', 'Negative', 'Negative', 'Negative', 'Negative',
#        'Negative', 'Negative'], dtype=object)
